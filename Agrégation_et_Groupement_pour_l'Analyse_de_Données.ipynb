# %% [markdown]
# <a href="https://colab.research.google.com/github/kaki-academy/Analyse-de-Donnees-avec-Pandas-Ma-trisez-Python-pour-le-Data-Science/blob/Agr%C3%A9gation-et-Groupement-pour-l'Analyse-de-Donn%C3%A9es/Agr%C3%A9gation_et_Groupement_pour_l'Analyse_de_Donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#creation de df

df = pd.DataFrame({
    'Categorie': ['A', 'B', 'A', 'B', 'C', 'A', 'B', 'C'],
    'Valeurs' : pd.Series([1,2,3,4,5,6,7,8])
})

moyenne = df.groupby('Categorie').mean()
moyenne
# Out:
#             Valeurs
# Categorie
# A          3.333333
# B          4.333333
# C          6.500000

# %%
#fonction pour calculer la somme

def calculate_sum(group) :
  #calculer la somme de la colonnes valeurs
  return group['Valeurs'].sum()


#utilisation de groupby + apply()
result = df.groupby('Categorie').apply(calculate_sum)

result
# Out:
# Categorie
# A    10
# B    13
# C    13
# dtype: int64

# %%
# Creating a DataFrame

df2 = pd.DataFrame(data)

# Converting 'Date' column to datetime

df2['date'] = pd.to_datetime(df2['date'])


# Grouping data by 'Date' and aggregating 'Sales' using sum

df_ventes = df2.groupby('date').agg({'ventes': 'sum'})

df_ventes
# Out:
#             ventes
# date
# 2023-01-01     350
# 2023-01-02     550
# 2023-01-03     100

# %%
#ajouter une nouvelle colonnes
df2["type_produit"] = ["A", 'B', 'A', 'B', 'A']

# Creation de table pivot
pivot = df2.pivot_table(values='ventes', index='date', columns='type_produit', aggfunc='sum')

pivot
# Out:
# type_produit      A      B
# date
# 2023-01-01    200.0  150.0
# 2023-01-02    300.0  250.0
# 2023-01-03    100.0    NaN

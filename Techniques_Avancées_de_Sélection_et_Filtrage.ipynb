# %% [markdown]
# <a href="https://colab.research.google.com/github/kaki-academy/Analyse-de-Donnees-avec-Pandas-Ma-trisez-Python-pour-le-Data-Science/blob/Techniques-Avanc%C3%A9es-de-S%C3%A9lection-et-Filtrage/Techniques_Avanc%C3%A9es_de_S%C3%A9lection_et_Filtrage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
chemin = '/content/drive/MyDrive/Colab Notebooks/DataSets/Population_and_GDP_Africa_2022.csv'
donnees = pd.read_csv(chemin)
donnees
# Out:
#         ID  Year Country    Continent  Population      GDP (USD)
# 0        1  2000  Uganda  East Africa     23303189  6.193247e+09
# 1        2  2001  Uganda  East Africa     24022603  5.840504e+09
# 2        3  2002  Uganda  East Africa     24781316  5.840504e+09
# 3        4  2003  Uganda  East Africa     25577246  6.606884e+09
# 4        5  2004  Uganda  East Africa     26403221  7.939488e+09
# ...    ...   ...     ...          ...          ...           ...
# 1329  1330  2018    Togo  West Africa      7794569  7.029218e+09
# 1330  1331  2019    Togo  West Africa      7986521  6.992656e+09
# 1331  1332  2020    Togo  West Africa      8181085  7.389329e+09
# 1332  1333  2021    Togo  West Africa      8399356  8.334047e+09
# 1333  1334  2022    Togo  West Africa      8623451  8.126439e+09
#
# [1334 rows x 6 columns]

# %%
donnees["GDP (USD)"] = donnees["GDP (USD)"].fillna(donnees["GDP (USD)"].mean())
donnees
# Out:
#         ID  Year Country    Continent  Population      GDP (USD)
# 0        1  2000  Uganda  East Africa     23303189  6.193247e+09
# 1        2  2001  Uganda  East Africa     24022603  5.840504e+09
# 2        3  2002  Uganda  East Africa     24781316  5.840504e+09
# 3        4  2003  Uganda  East Africa     25577246  6.606884e+09
# 4        5  2004  Uganda  East Africa     26403221  7.939488e+09
# ...    ...   ...     ...          ...          ...           ...
# 1329  1330  2018    Togo  West Africa      7794569  7.029218e+09
# 1330  1331  2019    Togo  West Africa      7986521  6.992656e+09
# 1331  1332  2020    Togo  West Africa      8181085  7.389329e+09
# 1332  1333  2021    Togo  West Africa      8399356  8.334047e+09
# 1333  1334  2022    Togo  West Africa      8623451  8.126439e+09
#
# [1334 rows x 6 columns]

# %%
donnees.columns = donnees.columns.str.strip()

# %%
pays_100 = donnees[donnees["Population"] > 100000000]
pays_100
# Out:
#         ID  Year   Country     Continent  Population     GDP (USD)
# 430    431  2016  Ethiopia   East Africa   102227020  7.429675e+10
# 431    432  2017  Ethiopia   East Africa   105013186  8.177089e+10
# 432    433  2018  Ethiopia   East Africa   107823775  8.426920e+10
# 433    434  2019  Ethiopia   East Africa   110663299  9.591261e+10
# 434    435  2020  Ethiopia   East Africa   113529037  1.076577e+11
# 435    436  2021  Ethiopia   East Africa   116401322  1.112619e+11
# 436    437  2022  Ethiopia   East Africa   119346275  1.267835e+11
# 526    527  2020     Egypt  North Africa   101366557  3.838178e+11
# 527    528  2021     Egypt  North Africa   103578375  4.246718e+11
# 528    529  2022     Egypt  North Africa   105838455  4.767477e+11
# 1219  1220  2000   Nigeria   West Africa   120780216  6.944896e+10
# 1220  1221  2001   Nigeria   West Africa   123851731  7.403056e+10
# 1221  1222  2002   Nigeria   West Africa   127008222  9.505409e+10
# ...

# %%
pib_popu = donnees[(donnees['GDP (USD)'] > 500000000) & (donnees['Population'] < 50000000)]
pib_popu
# Out:
#         ID  Year Country    Continent  Population     GDP (USD)
# 0        1  2000  Uganda  East Africa    23303189  6.193247e+09
# 1        2  2001  Uganda  East Africa    24022603  5.840504e+09
# 2        3  2002  Uganda  East Africa    24781316  5.840504e+09
# 3        4  2003  Uganda  East Africa    25577246  6.606884e+09
# 4        5  2004  Uganda  East Africa    26403221  7.939488e+09
# ...    ...   ...     ...          ...         ...           ...
# 1329  1330  2018    Togo  West Africa     7794569  7.029218e+09
# 1330  1331  2019    Togo  West Africa     7986521  6.992656e+09
# 1331  1332  2020    Togo  West Africa     8181085  7.389329e+09
# 1332  1333  2021    Togo  West Africa     8399356  8.334047e+09
# 1333  1334  2022    Togo  West Africa     8623451  8.126439e+09
#
# [1190 rows x 6 columns]

# %%
critere = (donnees['Continent'] == 'West Africa') | (donnees['GDP (USD)'] / donnees['Population'] > 20000)
pays_critere = donnees[critere]
pays_critere
# Out:
#         ID  Year  Country    Continent  Population     GDP (USD)
# 207    208  2000  Mayotte  East Africa      147645  3.622274e+10
# 208    209  2001  Mayotte  East Africa      153066  3.622274e+10
# 209    210  2002  Mayotte  East Africa      158502  3.622274e+10
# 210    211  2003  Mayotte  East Africa      163982  3.622274e+10
# 211    212  2004  Mayotte  East Africa      169545  3.622274e+10
# ...    ...   ...      ...          ...         ...           ...
# 1329  1330  2018     Togo  West Africa     7794569  7.029218e+09
# 1330  1331  2019     Togo  West Africa     7986521  6.992656e+09
# 1331  1332  2020     Togo  West Africa     8181085  7.389329e+09
# 1332  1333  2021     Togo  West Africa     8399356  8.334047e+09
# 1333  1334  2022     Togo  West Africa     8623451  8.126439e+09
#
# [465 rows x 6 columns]

# %%
pays_query = donnees.query('(`GDP (USD)` > 1e12) != (`Population` > 200000000) and Year == 2022 and Continent == "West Africa" ')
pays_query
# Out:
#         ID  Year  Country    Continent  Population     GDP (USD)
# 1241  1242  2022  Nigeria  West Africa   214568727  4.773861e+11

# %%
moyenne = donnees.groupby('Continent')['GDP (USD)'].transform('mean')
pib_sup = donnees[donnees['GDP (USD)'] > moyenne]
pib_sup
# Out:
#         ID  Year                                       Country    Continent  \
# 9       10  2009                                        Uganda  East Africa
# 10      11  2010                                        Uganda  East Africa
# 11      12  2011                                        Uganda  East Africa
# 12      13  2012                                        Uganda  East Africa
# 13      14  2013                                        Uganda  East Africa
# ...    ...   ...                                           ...          ...
# 1260  1261  2018  Saint Helena, Ascension and Tristan da Cunha  West Africa
# 1261  1262  2019  Saint Helena, Ascension and Tristan da Cunha  West Africa
# 1262  1263  2020  Saint Helena, Ascension and Tristan da Cunha  West Africa
# 1263  1264  2021  Saint Helena, Ascension and Tristan da Cunha  West Africa
# 1264  1265  2022  Saint Helena, Ascension and Tristan da Cunha  West Africa
#
#       Population     GDP (USD)
# ...

# %%
donnees_eco = donnees.loc[donnees['Population'] > 100000000, ['Country', 'GDP (USD)', 'Population']]
donnees_eco
# Out:
#        Country     GDP (USD)  Population
# 430   Ethiopia  7.429675e+10   102227020
# 431   Ethiopia  8.177089e+10   105013186
# 432   Ethiopia  8.426920e+10   107823775
# 433   Ethiopia  9.591261e+10   110663299
# 434   Ethiopia  1.076577e+11   113529037
# 435   Ethiopia  1.112619e+11   116401322
# 436   Ethiopia  1.267835e+11   119346275
# 526      Egypt  3.838178e+11   101366557
# 527      Egypt  4.246718e+11   103578375
# 528      Egypt  4.767477e+11   105838455
# 1219   Nigeria  6.944896e+10   120780216
# 1220   Nigeria  7.403056e+10   123851731
# 1221   Nigeria  9.505409e+10   127008222
# 1222   Nigeria  1.047390e+11   130261937
# 1223   Nigeria  1.357647e+11   133619871
# 1224   Nigeria  1.756705e+11   137107284
# 1225   Nigeria  2.384550e+11   140716755
# 1226   Nigeria  2.782608e+11   144454761
# 1227   Nigeria  3.394762e+11   148315533
# 1228   Nigeria  2.950088e+11   152313946
# 1229   Nigeria  3.669905e+11   156431242
# 1230   Nigeria  4.144665e+11   160671820
# ...

# %%
colonnes_population = donnees.filter(like = 'Population')
colonnes_population
# Out:
#       Population
# 0       23303189
# 1       24022603
# 2       24781316
# 3       25577246
# 4       26403221
# ...          ...
# 1329     7794569
# 1330     7986521
# 1331     8181085
# 1332     8399356
# 1333     8623451
#
# [1334 rows x 1 columns]

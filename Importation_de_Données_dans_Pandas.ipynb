# %% [markdown]
# <a href="https://colab.research.google.com/github/kaki-academy/Analyse-de-Donnees-avec-Pandas-Ma-trisez-Python-pour-le-Data-Science/blob/Importation-et-manipulation-de-Donnees-dans-Pandas/Importation_de_Donn%C3%A9es_dans_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# Charger un CSV

chemin = '/content/drive/MyDrive/Colab Notebooks/DataSets/Population_and_GDP_Africa_2022.csv'
donnees = pd.read_csv(chemin)
donnees
# Out:
#         ID  Year Country    Continent  Population      GDP (USD)
# 0        1  2000  Uganda  East Africa     23303189  6.193247e+09
# 1        2  2001  Uganda  East Africa     24022603  5.840504e+09
# 2        3  2002  Uganda  East Africa     24781316  5.840504e+09
# 3        4  2003  Uganda  East Africa     25577246  6.606884e+09
# 4        5  2004  Uganda  East Africa     26403221  7.939488e+09
# ...    ...   ...     ...          ...          ...           ...
# 1329  1330  2018    Togo  West Africa      7794569  7.029218e+09
# 1330  1331  2019    Togo  West Africa      7986521  6.992656e+09
# 1331  1332  2020    Togo  West Africa      8181085  7.389329e+09
# 1332  1333  2021    Togo  West Africa      8399356  8.334047e+09
# 1333  1334  2022    Togo  West Africa      8623451  8.126439e+09
#
# [1334 rows x 6 columns]

# %%
test = pd.read_csv(chemin, sep=';', header=None)
test
# Out:
#                                                      0
# 0      ID,Year,Country,Continent,Population ,GDP (USD)
# 1      1,2000,Uganda,East Africa,23303189,6193246837.1
# 2     2,2001,Uganda,East Africa,24022603,5840503868.57
# 3     3,2002,Uganda,East Africa,24781316,5840503868.57
# 4     4,2003,Uganda,East Africa,25577246,6606884273.85
# ...                                                ...
# 1330  1330,2018,Togo,West Africa,7794569,7029217931.75
# 1331  1331,2019,Togo,West Africa,7986521,6992656428.94
# 1332  1332,2020,Togo,West Africa,8181085,7389329392.77
# 1333  1333,2021,Togo,West Africa,8399356,8334047485.51
# 1334  1334,2022,Togo,West Africa,8623451,8126439480.61
#
# [1335 rows x 1 columns]

# %%
donnees.head()
#head() affiche les premieres lignes du DF
# Out:
#    ID  Year Country    Continent  Population      GDP (USD)
# 0   1  2000  Uganda  East Africa     23303189  6.193247e+09
# 1   2  2001  Uganda  East Africa     24022603  5.840504e+09
# 2   3  2002  Uganda  East Africa     24781316  5.840504e+09
# 3   4  2003  Uganda  East Africa     25577246  6.606884e+09
# 4   5  2004  Uganda  East Africa     26403221  7.939488e+09

# %%
donnees.info()
#fournit un resume du DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1334 entries, 0 to 1333
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1334 non-null   int64
#  1   Year         1334 non-null   int64
#  2   Country      1334 non-null   object
#  3   Continent    1334 non-null   object
#  4   Population   1334 non-null   int64
#  5   GDP (USD)    1179 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 62.7+ KB

# %%
donnees.isnull().sum()
# Out:
# ID               0
# Year             0
# Country          0
# Continent        0
# Population       0
# GDP (USD)      155
# dtype: int64

# %%
donnees["GDP (USD)"] = donnees["GDP (USD)"].fillna(donnees["GDP (USD)"].mean())
donnees
# Out:
#         ID  Year Country    Continent  Population      GDP (USD)
# 0        1  2000  Uganda  East Africa     23303189  6.193247e+09
# 1        2  2001  Uganda  East Africa     24022603  5.840504e+09
# 2        3  2002  Uganda  East Africa     24781316  5.840504e+09
# 3        4  2003  Uganda  East Africa     25577246  6.606884e+09
# 4        5  2004  Uganda  East Africa     26403221  7.939488e+09
# ...    ...   ...     ...          ...          ...           ...
# 1329  1330  2018    Togo  West Africa      7794569  7.029218e+09
# 1330  1331  2019    Togo  West Africa      7986521  6.992656e+09
# 1331  1332  2020    Togo  West Africa      8181085  7.389329e+09
# 1332  1333  2021    Togo  West Africa      8399356  8.334047e+09
# 1333  1334  2022    Togo  West Africa      8623451  8.126439e+09
#
# [1334 rows x 6 columns]

# %%
donnees.sort_values(by='GDP (USD)', ascending=False, inplace=True)
donnees
# Out:
#         ID  Year                Country       Continent  Population   \
# 1233  1234  2014                Nigeria     West Africa    174104440
# 1232  1233  2013                Nigeria     West Africa    169515956
# 1234  1235  2015                Nigeria     West Africa    178790641
# 1241  1242  2022                Nigeria     West Africa    214568727
# 528    529  2022                  Egypt    North Africa    105838455
# ...    ...   ...                    ...             ...          ...
# 856    857  2005  Sao Tome and Principe  Central Africa       155619
# 855    856  2004  Sao Tome and Principe  Central Africa       152080
# 854    855  2003  Sao Tome and Principe  Central Africa       148940
# 853    854  2002  Sao Tome and Principe  Central Africa       146116
# 852    853  2001  Sao Tome and Principe  Central Africa       143522
#
#          GDP (USD)
# 1233  5.741838e+11
# 1232  5.201172e+11
# 1234  4.930268e+11
# 1241  4.773861e+11
# 528   4.767477e+11
# ...

# %%
country_count = donnees["Country"].value_counts()
country_count
# Out:
# Nigeria                                         23
# Malawi                                          23
# Botswana                                        23
# Burkina Faso                                    23
# Mali                                            23
# Republic of the Congo                           23
# Mozambique                                      23
# Benin                                           23
# Madagascar                                      23
# Niger                                           23
# Mauritius                                       23
# Chad                                            23
# Namibia                                         23
# Rwanda                                          23
# Mauritania                                      23
# Egypt                                           23
# Togo                                            23
# Sierra Leone                                    23
# ...

# %%
print(donnees.columns)
# Out:
# Index(['ID', 'Year', 'Country', 'Continent', 'Population ', 'GDP (USD)'], dtype='object')

# %%
donnees.columns = donnees.columns.str.strip()
